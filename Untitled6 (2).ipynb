# %%
import pandas as pd
import csv
import plotly.graph_objects as fr
import plotly.express as px
import plotly.figure_factory as ff
import statistics
import random
from statistics import mode
from statistics import mean

# %%
from google.colab import files
data_upload = files.upload()
# Out:
#      <input type="file" id="files-f1a830c9-4497-4419-8b8c-25f8e3e316e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1a830c9-4497-4419-8b8c-25f8e3e316e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
data_upload
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
mean1 = statistics.mean(df['math score'])
mean2 = statistics.mean(df['reading score'])
mean3 = statistics.mean(df['writing score'])
g = statistics.median(df['math score'])
h = statistics.median(df['reading score'])
i = statistics.median(df['writing score'])
list_1 = df['math score'].to_list()
list_2 = df['reading score'].to_list()
list_3 = df['writing score'].to_list()

# %%
std_deviation = statistics.stdev(list_1)
std_deviation2 = statistics.stdev(list_2)
std_deviation3 = statistics.stdev(list_3)
#Finding 1 standard deviation stard and end values, and 2 standard deviations stard and end values
first_std_deviation_start, first_std_deviation_end = mean1 - std_deviation, mean1 + std_deviation
second_std_deviation_start, second_std_deviation_end = mean1-(2*std_deviation), mean1+(2*std_deviation)
third_std_deviation_start, third_std_deviation_end = mean1-(3*std_deviation), mean1+(3*std_deviation)
fourth_std_deviation_start, fourth_std_deviation_end = mean2 - std_deviation2, mean2 + std_deviation2
fifth_std_deviation_start, fifth_std_deviation_end = mean2-(2*std_deviation2), mean2+(2*std_deviation2)
sixth_std_deviation_start, sixth_std_deviation_end = mean2-(3*std_deviation2), mean2+(3*std_deviation2)
seventh_std_deviation_start, seventh_std_deviation_end = mean3 - std_deviation3, mean3 + std_deviation3
eighth_std_deviation_start, eighth_std_deviation_end = mean3-(2*std_deviation3), mean3+(2*std_deviation3)
ninth_std_deviation_start, ninth_std_deviation_end = mean3-(3*std_deviation3), mean3+(3*std_deviation3)

# %%
list_of_data_within_1_std_deviation = [result for result in list_1 if result > first_std_deviation_start and result < first_std_deviation_end]
list_of_data_within_2_std_deviation = [result for result in list_1 if result > second_std_deviation_start and result < second_std_deviation_end]
list_of_data_within_3_std_deviation = [result for result in list_1 if result > third_std_deviation_start and result < third_std_deviation_end]
list_of_data_within_4_std_deviation = [result for result in list_2 if result > fourth_std_deviation_start and result < fourth_std_deviation_end]
list_of_data_within_5_std_deviation = [result for result in list_2 if result > fifth_std_deviation_start and result < fifth_std_deviation_end]
list_of_data_within_6_std_deviation = [result for result in list_2 if result > sixth_std_deviation_start and result < sixth_std_deviation_end]
list_of_data_within_7_std_deviation = [result for result in list_3 if result > seventh_std_deviation_start and result < seventh_std_deviation_end]
list_of_data_within_8_std_deviation = [result for result in list_3 if result > eighth_std_deviation_start and result < eighth_std_deviation_end]
list_of_data_within_9_std_deviation = [result for result in list_3 if result > ninth_std_deviation_start and result < ninth_std_deviation_end]
print("Standard deviation of this data is {}".format(std_deviation))
print("{}% of data lies within 1 standard deviation for Math Score".format(len(list_of_data_within_1_std_deviation)*100.0/len(list_1)))
print("{}% of data lies within 2 standard deviations for Math Score".format(len(list_of_data_within_2_std_deviation)*100.0/len(list_1)))
print("{}% of data lies within 3 standard deviations for Math Score".format(len(list_of_data_within_3_std_deviation)*100.0/len(list_1)))
print("{}% of data lies within 1 standard deviation for Reading Score".format(len(list_of_data_within_4_std_deviation)*100.0/len(list_2)))
print("{}% of data lies within 2 standard deviations for Reading Score".format(len(list_of_data_within_5_std_deviation)*100.0/len(list_2)))
print("{}% of data lies within 3 standard deviations for Reading Score".format(len(list_of_data_within_6_std_deviation)*100.0/len(list_2)))
print("{}% of data lies within 1 standard deviation for Writing Score".format(len(list_of_data_within_7_std_deviation)*100.0/len(list_3)))
print("{}% of data lies within 2 standard deviations for Writing Score".format(len(list_of_data_within_8_std_deviation)*100.0/len(list_3)))
print("{}% of data lies within 3 standard deviations for Writing Score".format(len(list_of_data_within_9_std_deviation)*100.0/len(list_3)))
# Out:
# Standard deviation of this data is 15.163080096009452
# 69.6% of data lies within 1 standard deviation for Math Score
# 95.4% of data lies within 2 standard deviations for Math Score
# 99.6% of data lies within 3 standard deviations for Math Score
# 66.4% of data lies within 1 standard deviation for Reading Score
# 95.4% of data lies within 2 standard deviations for Reading Score
# 99.6% of data lies within 3 standard deviations for Reading Score
# 68.8% of data lies within 1 standard deviation for Writing Score
# 95.8% of data lies within 2 standard deviations for Writing Score
# 99.6% of data lies within 3 standard deviations for Writing Score
